# %%
import google.generativeai as genai
import os
import subprocess

# Configure the Google Generative AI API
api_key = 'AIzaSyCBvgGAav5RbTUVYK4w_wS04vueP5nX3Ok'
genai.configure(api_key=api_key)

# Function to read content from a .txt file
def read_txt(file_path):
    try:
        with open(file_path, 'r', encoding='utf-8') as file:
            return file.read()  # Read the entire file content
    except Exception as e:
        print(f"Error reading file: {e}")
        return ""

# Function to write content to a .txt file
def write_txt(file_path, content):
    try:
        with open(file_path, 'w', encoding='utf-8') as file:
            file.write(content)
    except Exception as e:
        print(f"Error writing to file: {e}")

# Function to run make command and capture output
def run_make():
    try:
        result = subprocess.run(["make"], capture_output=True, text=True)
        return result.returncode, result.stdout, result.stderr
    except Exception as e:
        print(f"Error running make: {e}")
        return -1, "", str(e)

# Read the C++ code from the files
cpp_code = read_txt("/home/sl3489/ece6775_project/ece6775-final-project/finalproject/lab2/lab2/digitrecGen.cpp")

# Create the initial prompt with the code included
prompt = f"Optimize the provided HLS code `digitrecGen.c` to produce `digitrec.c` by adding HLS pragmas or directives that minimize latency by roughly one order of magnitude while maintaining the original functionality. Focus on applying loop unrolling to inner loops for parallelism (avoiding unrolling the outermost loop with 1800 iterations to control chip area) and array partitioning to split arrays into smaller arrays, increasing read/write ports for storage. Use only fixed-bound loops, and ensure the baseline code structure remains unchanged apart from the added pragmas or directives. Refer to Vivado HLS User Guide UG902 (v2019.2) for details on applying loop unrolling (p.458) and array partitioning (p.426). The final design should preserve functionality while achieving a significant reduction in latency. Here is the digitrecGen.cpp code:\n\n{cpp_code}"

# Initialize variables for tracking attempts
attempts = 1
max_attempts = 15  # Set a limit to avoid infinite loops

while attempts < max_attempts:
    # Send the API request
    try:
        response = genai.GenerativeModel('gemini-pro').generate_content(prompt)
    except Exception as e:
        print(f"Error during API request: {e}")
        break

    # Check if the response is valid
    if response and response.text:
        response_content = response.text

        # Extract the code part from the response
        import re
        code_block = re.search(r'```(.*?)```', response_content, re.DOTALL)
        if code_block:
            code_content = code_block.group(1).strip()
        else:
            code_content = response_content.strip()

        # Remove any leading "cpp" from the code content
        if code_content.startswith("cpp"):
            code_content = code_content[3:].strip()

        # Write the code content to a file
        output_file_path = "/home/sl3489/ece6775_project/ece6775-final-project/finalproject/lab2/lab2/digitrec.cpp"
        write_txt(output_file_path, code_content)
        print(f"Output written to {output_file_path}")

        # Run make command
        returncode, stdout, stderr = run_make()
        print(stdout)
        print(stderr)

        if returncode == 0:
            print("Compilation successful!")
            break
        else:
            print("Compilation failed. Updating prompt with error messages.")
            prompt += f"\n\nThe compilation failed with the following errors:\n{stderr}"
            attempts += 1
    else:
        print("Invalid response from API.")
        break

print(f"Compilation attempts: {attempts}")
# Out:
# Output written to /home/sl3489/ece6775_project/ece6775-final-project/finalproject/lab2/lab2/digitrec.cpp
# g++ -g -I/opt/xilinx/Vivado/2019.2/include -DK_CONST=3 digitrec.cpp digitrec_test.cpp -o digitrec_3-nn_tb
#
# digitrec.cpp:21:48: error: stray ‘#’ in program
#    knn_init_outer: for (int i = 0; i < 10; ++i) #pragma HLS UNROLL
#                                                 ^
# digitrec.cpp:22:55: error: stray ‘#’ in program
#      knn_init_inner: for (int k = 0; k < K_CONST; ++k) #pragma HLS UNROLL
#                                                        ^
# digitrec.cpp:29:61: error: stray ‘#’ in program
#    training_outer: for (int i = 0; i < TRAINING_SIZE; i+=32) #pragma HLS PIPELINE
#                                                              ^
# digitrec.cpp:31:50: error: stray ‘#’ in program
#      training_inner: for (int j = 0; j < 10; ++j) #pragma HLS UNROLL
#                                                   ^
# digitrec.cpp:62:42: error: stray ‘#’ in program
#    popcount: for (int i = 0; i < 49; ++i) #pragma HLS UNROLL
#                                           ^
# digitrec.cpp:71:47: error: stray ‘#’ in program
#    find_min: for (int i = 1; i < K_CONST; ++i) #pragma HLS UNROLL
#                                                ^
# digitrec.cpp:104:47: error: stray ‘#’ in program
#    flatten_outer:for (bit4 i = 0; i < 10; i++) #pragma HLS UNROLL
#                                                ^
# digitrec.cpp:105:53: error: stray ‘#’ in program
#      flatten_inner:for (int j = 0; j < K_CONST; j++) #pragma HLS UNROLL
#                                                      ^
# digitrec.cpp:113:57: error: stray ‘#’ in program
#    bubble_outer: for (int i = 0; i < NUM_ENTRIES; i+=32) #pragma HLS PIPELINE
#                                                          ^
# digitrec.cpp:114:61: error: stray ‘#’ in program
#      bubble_inner: for (int j = 0; j < NUM_ENTRIES - 1; j++) #pragma HLS UNROLL
#                                                              ^
# digitrec.cpp:150:49: error: stray ‘#’ in program
#    knn_outer: for (bit4 i = 0; i < K_CONST; i++) #pragma HLS UNROLL
#                                                  ^
# digitrec.cpp:156:46: error: stray ‘#’ in program
#    count_outer: for (bit4 i = 0; i < 10; i++) #pragma HLS UNROLL
#                                               ^
# digitrec.cpp:159:53: error: stray ‘#’ in program
#      count_inner: for (bit4 j = 0; j < K_CONST; j++) #pragma HLS UNROLL
#                                                      ^
# digitrec.cpp: In function ‘bit4 digitrec(digit)’:
# digitrec.cpp:18:28: error: expected initializer before numeric constant
#    bit6 knn_set[10][K_CONST]2;
#                             ^
# digitrec.cpp:21:49: error: ‘pragma’ was not declared in this scope
#    knn_init_outer: for (int i = 0; i < 10; ++i) #pragma HLS UNROLL
#                                                  ^~~~~~
# digitrec.cpp:21:49: note: suggested alternative: ‘_Pragma’
#    knn_init_outer: for (int i = 0; i < 10; ++i) #pragma HLS UNROLL
#                                                  ^~~~~~
#                                                  _Pragma
# digitrec.cpp:22:37: error: ‘k’ was not declared in this scope
#      knn_init_inner: for (int k = 0; k < K_CONST; ++k) #pragma HLS UNROLL
#                                      ^
# digitrec.cpp:29:62: error: ‘pragma’ was not declared in this scope
#    training_outer: for (int i = 0; i < TRAINING_SIZE; i+=32) #pragma HLS PIPELINE
#                                                               ^~~~~~
# digitrec.cpp:29:62: note: suggested alternative: ‘_Pragma’
#    training_outer: for (int i = 0; i < TRAINING_SIZE; i+=32) #pragma HLS PIPELINE
#                                                               ^~~~~~
#                                                               _Pragma
# digitrec.cpp:31:37: error: ‘j’ was not declared in this scope
#      training_inner: for (int j = 0; j < 10; ++j) #pragma HLS UNROLL
#                                      ^
# digitrec.cpp:31:37: note: suggested alternative: ‘jn’
#      training_inner: for (int j = 0; j < 10; ++j) #pragma HLS UNROLL
#                                      ^
#                                      jn
# digitrec.cpp:36:25: error: ‘training_instance’ was not declared in this scope
#        update_knn(input, training_instance, knn_set[j]);
#                          ^~~~~~~~~~~~~~~~~
# digitrec.cpp:36:25: note: suggested alternative: ‘training_data’
#        update_knn(input, training_instance, knn_set[j]);
#                          ^~~~~~~~~~~~~~~~~
#                          training_data
# digitrec.cpp:36:44: error: ‘knn_set’ was not declared in this scope
#        update_knn(input, training_instance, knn_set[j]);
#                                             ^~~~~~~
# digitrec.cpp:36:44: note: suggested alternative: ‘knn_vote’
#        update_knn(input, training_instance, knn_set[j]);
#                                             ^~~~~~~
#                                             knn_vote
# digitrec.cpp:37:3: warning: no return statement in function returning non-void [-Wreturn-type]
#    }
#    ^
# digitrec.cpp: At global scope:
# digitrec.cpp:40:3: error: expected unqualified-id before ‘return’
#    return knn_vote(knn_set);
#    ^~~~~~
# digitrec.cpp:41:1: error: expected declaration before ‘}’ token
#  }
#  ^
# make: *** [Makefile:30: digitrec_3-nn_tb] Error 1
#
# Compilation failed. Updating prompt with error messages.
# Output written to /home/sl3489/ece6775_project/ece6775-final-project/finalproject/lab2/lab2/digitrec.cpp
# g++ -g -I/opt/xilinx/Vivado/2019.2/include -DK_CONST=3 digitrec.cpp digitrec_test.cpp -o digitrec_3-nn_tb
#
# digitrec.cpp:1:1: error: ‘c’ does not name a type
#  c
#  ^
# In file included from /opt/xilinx/Vivado/2019.2/include/ap_common.h:57,
#                  from /opt/xilinx/Vivado/2019.2/include/ap_int.h:54,
#                  from typedefs.h:9,
#                  from digitrec.h:9,
#                  from digitrec.cpp:7:
# /opt/xilinx/Vivado/2019.2/include/ap_decl.h:197:52: error: ‘ap_q_mode’ has not been declared
#  template <int _AP_W, int _AP_I, bool _AP_S = true, ap_q_mode _AP_Q = AP_TRN,
#                                                     ^~~~~~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_decl.h:197:70: error: ‘AP_TRN’ was not declared in this scope
#  template <int _AP_W, int _AP_I, bool _AP_S = true, ap_q_mode _AP_Q = AP_TRN,
#                                                                       ^~~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_decl.h:197:70: note: suggested alternative: ‘AP_MIN’
#  template <int _AP_W, int _AP_I, bool _AP_S = true, ap_q_mode _AP_Q = AP_TRN,
#                                                                       ^~~~~~
#                                                                       AP_MIN
# /opt/xilinx/Vivado/2019.2/include/ap_decl.h:201:33: error: ‘ap_q_mode’ has not been declared
#  template <int _AP_W, int _AP_I, ap_q_mode _AP_Q = AP_TRN,
#                                  ^~~~~~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_decl.h:201:51: error: ‘AP_TRN’ was not declared in this scope
#  template <int _AP_W, int _AP_I, ap_q_mode _AP_Q = AP_TRN,
#                                                    ^~~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_decl.h:201:51: note: suggested alternative: ‘AP_MIN’
#  template <int _AP_W, int _AP_I, ap_q_mode _AP_Q = AP_TRN,
#                                                    ^~~~~~
#                                                    AP_MIN
# /opt/xilinx/Vivado/2019.2/include/ap_decl.h:205:33: error: ‘ap_q_mode’ has not been declared
#  template <int _AP_W, int _AP_I, ap_q_mode _AP_Q = AP_TRN,
#                                  ^~~~~~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_decl.h:205:51: error: ‘AP_TRN’ was not declared in this scope
#  template <int _AP_W, int _AP_I, ap_q_mode _AP_Q = AP_TRN,
#                                                    ^~~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_decl.h:205:51: note: suggested alternative: ‘AP_MIN’
#  template <int _AP_W, int _AP_I, ap_q_mode _AP_Q = AP_TRN,
#                                                    ^~~~~~
#                                                    AP_MIN
# /opt/xilinx/Vivado/2019.2/include/ap_decl.h:209:45: error: ‘ap_q_mode’ has not been declared
#  template <int _AP_W, int _AP_I, bool _AP_S, ap_q_mode _AP_Q, ap_o_mode _AP_O,
#                                              ^~~~~~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_decl.h:211:8: error: no default argument for ‘_AP_O’
#  struct af_range_ref;
#         ^~~~~~~~~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_decl.h:211:8: error: no default argument for ‘_AP_N’
# /opt/xilinx/Vivado/2019.2/include/ap_decl.h:213:45: error: ‘ap_q_mode’ has not been declared
#  template <int _AP_W, int _AP_I, bool _AP_S, ap_q_mode _AP_Q, ap_o_mode _AP_O,
#                                              ^~~~~~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_decl.h:215:8: error: no default argument for ‘_AP_O’
#  struct af_bit_ref;
#         ^~~~~~~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_decl.h:215:8: error: no default argument for ‘_AP_N’
# In file included from /opt/xilinx/Vivado/2019.2/include/etc/ap_private.h:90,
#                  from /opt/xilinx/Vivado/2019.2/include/ap_common.h:641,
#                  from /opt/xilinx/Vivado/2019.2/include/ap_int.h:54,
#                  from typedefs.h:9,
#                  from digitrec.h:9,
#                  from digitrec.cpp:7:
# /opt/xilinx/Vivado/2019.2/include/hls_half.h:1014:46: error: ‘ap_q_mode’ has not been declared
#    template<int _AP_W, int _AP_I, bool _AP_S, ap_q_mode _AP_Q, ap_o_mode _AP_O, int _AP_N>
#                                               ^~~~~~~~~
# /opt/xilinx/Vivado/2019.2/include/hls_half.h:1015:49: error: ‘_AP_Q’ was not declared in this scope
#    half(const ap_fixed_base<_AP_W, _AP_I, _AP_S, _AP_Q, _AP_O, _AP_N>& rhs) {
#                                                  ^~~~~
# /opt/xilinx/Vivado/2019.2/include/hls_half.h:1015:49: note: suggested alternative: ‘_AP_N’
#    half(const ap_fixed_base<_AP_W, _AP_I, _AP_S, _AP_Q, _AP_O, _AP_N>& rhs) {
#                                                  ^~~~~
#                                                  _AP_N
# /opt/xilinx/Vivado/2019.2/include/hls_half.h:1015:68: error: template argument 4 is invalid
#    half(const ap_fixed_base<_AP_W, _AP_I, _AP_S, _AP_Q, _AP_O, _AP_N>& rhs) {
#                                                                     ^
# /opt/xilinx/Vivado/2019.2/include/hls_half.h: In constructor ‘half::half(const int&)’:
# /opt/xilinx/Vivado/2019.2/include/hls_half.h:1017:16: error: request for member ‘to_half’ in ‘rhs’, which is of non-class type ‘const int’
#     *this = rhs.to_half();
#                 ^~~~~~~
# In file included from /opt/xilinx/Vivado/2019.2/include/ap_common.h:641,
#                  from /opt/xilinx/Vivado/2019.2/include/ap_int.h:54,
#                  from typedefs.h:9,
#                  from digitrec.h:9,
#                  from digitrec.cpp:7:
# /opt/xilinx/Vivado/2019.2/include/etc/ap_private.h: At global scope:
# /opt/xilinx/Vivado/2019.2/include/etc/ap_private.h:3145:50: error: ‘ap_q_mode’ has not been declared
#    template <int _AP_W2, int _AP_I2, bool _AP_S2, ap_q_mode _AP_Q2,
#                                                   ^~~~~~~~~
# /opt/xilinx/Vivado/2019.2/include/etc/ap_private.h:3147:17: error: no default argument for ‘_AP_O2’
#    friend struct ap_fixed_base;
#                  ^~~~~~~~~~~~~
# /opt/xilinx/Vivado/2019.2/include/etc/ap_private.h:3147:17: error: no default argument for ‘_AP_N2’
# /opt/xilinx/Vivado/2019.2/include/etc/ap_private.h:3147:17: error: default template arguments may not be used in template friend declarations
# In file included from /opt/xilinx/Vivado/2019.2/include/ap_common.h:641,
#                  from /opt/xilinx/Vivado/2019.2/include/ap_int.h:54,
#                  from typedefs.h:9,
#                  from digitrec.h:9,
#                  from digitrec.cpp:7:
# /opt/xilinx/Vivado/2019.2/include/etc/ap_private.h:6313:50: error: ‘ap_q_mode’ has not been declared
#    template <int _AP_W2, int _AP_I2, bool _AP_S2, ap_q_mode _AP_Q2,
#                                                   ^~~~~~~~~
# /opt/xilinx/Vivado/2019.2/include/etc/ap_private.h:6316:51: error: ‘_AP_Q2’ was not declared in this scope
#        const ap_fixed_base<_AP_W2, _AP_I2, _AP_S2, _AP_Q2, _AP_O2, _AP_N2>& val) {
#                                                    ^~~~~~
# /opt/xilinx/Vivado/2019.2/include/etc/ap_private.h:6316:51: note: suggested alternative: ‘_AP_N2’
#        const ap_fixed_base<_AP_W2, _AP_I2, _AP_S2, _AP_Q2, _AP_O2, _AP_N2>& val) {
#                                                    ^~~~~~
#                                                    _AP_N2
# /opt/xilinx/Vivado/2019.2/include/etc/ap_private.h:6316:73: error: template argument 4 is invalid
#        const ap_fixed_base<_AP_W2, _AP_I2, _AP_S2, _AP_Q2, _AP_O2, _AP_N2>& val) {
#                                                                          ^
# /opt/xilinx/Vivado/2019.2/include/etc/ap_private.h:6320:50: error: ‘ap_q_mode’ has not been declared
#    template <int _AP_W2, int _AP_I2, bool _AP_S2, ap_q_mode _AP_Q2,
#                                                   ^~~~~~~~~
# /opt/xilinx/Vivado/2019.2/include/etc/ap_private.h:6323:50: error: ‘_AP_Q2’ was not declared in this scope
#        const af_range_ref<_AP_W2, _AP_I2, _AP_S2, _AP_Q2, _AP_O2, _AP_N2>& val) {
#                                                   ^~~~~~
# /opt/xilinx/Vivado/2019.2/include/etc/ap_private.h:6323:50: note: suggested alternative: ‘_AP_N2’
#        const af_range_ref<_AP_W2, _AP_I2, _AP_S2, _AP_Q2, _AP_O2, _AP_N2>& val) {
#                                                   ^~~~~~
#                                                   _AP_N2
# /opt/xilinx/Vivado/2019.2/include/etc/ap_private.h:6323:72: error: template argument 4 is invalid
#        const af_range_ref<_AP_W2, _AP_I2, _AP_S2, _AP_Q2, _AP_O2, _AP_N2>& val) {
#                                                                         ^
# /opt/xilinx/Vivado/2019.2/include/etc/ap_private.h:6322:30: error: ‘template<int _AP_W, bool _AP_S> template<int _AP_W2, int _AP_I2, bool _AP_S2, <declaration error>, ap_o_mode _AP_O2, int _AP_N2> _private_range_ref<_AP_W, _AP_S>& _private_range_ref<_AP_W, _AP_S>::operator=(const int&)’ cannot be overloaded with ‘template<int _AP_W, bool _AP_S> template<int _AP_W2, int _AP_I2, bool _AP_S2, <declaration error>, ap_o_mode _AP_O2, int _AP_N2> _private_range_ref<_AP_W, _AP_S>& _private_range_ref<_AP_W, _AP_S>::operator=(const int&)’
#    INLINE _private_range_ref& operator=(
#                               ^~~~~~~~
# /opt/xilinx/Vivado/2019.2/include/etc/ap_private.h:6315:30: note: previous declaration ‘template<int _AP_W, bool _AP_S> template<int _AP_W2, int _AP_I2, bool _AP_S2, <declaration error>, ap_o_mode _AP_O2, int _AP_N2> _private_range_ref<_AP_W, _AP_S>& _private_range_ref<_AP_W, _AP_S>::operator=(const int&)’
#    INLINE _private_range_ref& operator=(
#                               ^~~~~~~~
# /opt/xilinx/Vivado/2019.2/include/etc/ap_private.h:6327:50: error: ‘ap_q_mode’ has not been declared
#    template <int _AP_W2, int _AP_I2, bool _AP_S2, ap_q_mode _AP_Q2,
#                                                   ^~~~~~~~~
# /opt/xilinx/Vivado/2019.2/include/etc/ap_private.h:6330:48: error: ‘_AP_Q2’ was not declared in this scope
#        const af_bit_ref<_AP_W2, _AP_I2, _AP_S2, _AP_Q2, _AP_O2, _AP_N2>& val) {
#                                                 ^~~~~~
# /opt/xilinx/Vivado/2019.2/include/etc/ap_private.h:6330:48: note: suggested alternative: ‘_AP_N2’
#        const af_bit_ref<_AP_W2, _AP_I2, _AP_S2, _AP_Q2, _AP_O2, _AP_N2>& val) {
#                                                 ^~~~~~
#                                                 _AP_N2
# /opt/xilinx/Vivado/2019.2/include/etc/ap_private.h:6330:70: error: template argument 4 is invalid
#        const af_bit_ref<_AP_W2, _AP_I2, _AP_S2, _AP_Q2, _AP_O2, _AP_N2>& val) {
#                                                                       ^
# /opt/xilinx/Vivado/2019.2/include/etc/ap_private.h:6329:30: error: ‘template<int _AP_W, bool _AP_S> template<int _AP_W2, int _AP_I2, bool _AP_S2, <declaration error>, ap_o_mode _AP_O2, int _AP_N2> _private_range_ref<_AP_W, _AP_S>& _private_range_ref<_AP_W, _AP_S>::operator=(const int&)’ cannot be overloaded with ‘template<int _AP_W, bool _AP_S> template<int _AP_W2, int _AP_I2, bool _AP_S2, <declaration error>, ap_o_mode _AP_O2, int _AP_N2> _private_range_ref<_AP_W, _AP_S>& _private_range_ref<_AP_W, _AP_S>::operator=(const int&)’
#    INLINE _private_range_ref& operator=(
#                               ^~~~~~~~
# /opt/xilinx/Vivado/2019.2/include/etc/ap_private.h:6315:30: note: previous declaration ‘template<int _AP_W, bool _AP_S> template<int _AP_W2, int _AP_I2, bool _AP_S2, <declaration error>, ap_o_mode _AP_O2, int _AP_N2> _private_range_ref<_AP_W, _AP_S>& _private_range_ref<_AP_W, _AP_S>::operator=(const int&)’
#    INLINE _private_range_ref& operator=(
#                               ^~~~~~~~
# /opt/xilinx/Vivado/2019.2/include/etc/ap_private.h: In member function ‘_private_range_ref<_AP_W, _AP_S>& _private_range_ref<_AP_W, _AP_S>::operator=(const int&)’:
# /opt/xilinx/Vivado/2019.2/include/etc/ap_private.h:6317:26: error: request for member ‘to_ap_int_base’ in ‘val’, which is of non-class type ‘const int’
#      return operator=(val.to_ap_int_base().V);
#                           ^~~~~~~~~~~~~~
# In file included from /opt/xilinx/Vivado/2019.2/include/ap_int.h:55,
#                  from typedefs.h:9,
#                  from digitrec.h:9,
#                  from digitrec.cpp:7:
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h: At global scope:
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:355:50: error: ‘ap_q_mode’ has not been declared
#    template <int _AP_W2, int _AP_I2, bool _AP_S2, ap_q_mode _AP_Q2,
#                                                   ^~~~~~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:358:51: error: ‘_AP_Q2’ was not declared in this scope
#        const ap_fixed_base<_AP_W2, _AP_I2, _AP_S2, _AP_Q2, _AP_O2, _AP_N2>& op) {
#                                                    ^~~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:358:51: note: suggested alternative: ‘_AP_N2’
#        const ap_fixed_base<_AP_W2, _AP_I2, _AP_S2, _AP_Q2, _AP_O2, _AP_N2>& op) {
#                                                    ^~~~~~
#                                                    _AP_N2
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:358:73: error: template argument 4 is invalid
#        const ap_fixed_base<_AP_W2, _AP_I2, _AP_S2, _AP_Q2, _AP_O2, _AP_N2>& op) {
#                                                                          ^
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:405:50: error: ‘ap_q_mode’ has not been declared
#    template <int _AP_W2, int _AP_I2, bool _AP_S2, ap_q_mode _AP_Q2,
#                                                   ^~~~~~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:408:50: error: ‘_AP_Q2’ was not declared in this scope
#        const af_range_ref<_AP_W2, _AP_I2, _AP_S2, _AP_Q2, _AP_O2, _AP_N2>& val) {
#                                                   ^~~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:408:50: note: suggested alternative: ‘_AP_N2’
#        const af_range_ref<_AP_W2, _AP_I2, _AP_S2, _AP_Q2, _AP_O2, _AP_N2>& val) {
#                                                   ^~~~~~
#                                                   _AP_N2
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:408:72: error: template argument 4 is invalid
#        const af_range_ref<_AP_W2, _AP_I2, _AP_S2, _AP_Q2, _AP_O2, _AP_N2>& val) {
#                                                                         ^
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:407:10: error: ‘template<int _AP_W, bool _AP_S> template<int _AP_W2, int _AP_I2, bool _AP_S2, <declaration error>, ap_o_mode _AP_O2, int _AP_N2> ap_int_base<_AP_W, _AP_S>::ap_int_base(const int&)’ cannot be overloaded with ‘template<int _AP_W, bool _AP_S> template<int _AP_W2, int _AP_I2, bool _AP_S2, <declaration error>, ap_o_mode _AP_O2, int _AP_N2> ap_int_base<_AP_W, _AP_S>::ap_int_base(const int&)’
#    INLINE ap_int_base(
#           ^~~~~~~~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:357:10: note: previous declaration ‘template<int _AP_W, bool _AP_S> template<int _AP_W2, int _AP_I2, bool _AP_S2, <declaration error>, ap_o_mode _AP_O2, int _AP_N2> ap_int_base<_AP_W, _AP_S>::ap_int_base(const int&)’
#    INLINE ap_int_base(
#           ^~~~~~~~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:412:50: error: ‘ap_q_mode’ has not been declared
#    template <int _AP_W2, int _AP_I2, bool _AP_S2, ap_q_mode _AP_Q2,
#                                                   ^~~~~~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:415:48: error: ‘_AP_Q2’ was not declared in this scope
#        const af_bit_ref<_AP_W2, _AP_I2, _AP_S2, _AP_Q2, _AP_O2, _AP_N2>& val) {
#                                                 ^~~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:415:48: note: suggested alternative: ‘_AP_N2’
#        const af_bit_ref<_AP_W2, _AP_I2, _AP_S2, _AP_Q2, _AP_O2, _AP_N2>& val) {
#                                                 ^~~~~~
#                                                 _AP_N2
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:415:70: error: template argument 4 is invalid
#        const af_bit_ref<_AP_W2, _AP_I2, _AP_S2, _AP_Q2, _AP_O2, _AP_N2>& val) {
#                                                                       ^
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:414:10: error: ‘template<int _AP_W, bool _AP_S> template<int _AP_W2, int _AP_I2, bool _AP_S2, <declaration error>, ap_o_mode _AP_O2, int _AP_N2> ap_int_base<_AP_W, _AP_S>::ap_int_base(const int&)’ cannot be overloaded with ‘template<int _AP_W, bool _AP_S> template<int _AP_W2, int _AP_I2, bool _AP_S2, <declaration error>, ap_o_mode _AP_O2, int _AP_N2> ap_int_base<_AP_W, _AP_S>::ap_int_base(const int&)’
#    INLINE ap_int_base(
#           ^~~~~~~~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:357:10: note: previous declaration ‘template<int _AP_W, bool _AP_S> template<int _AP_W2, int _AP_I2, bool _AP_S2, <declaration error>, ap_o_mode _AP_O2, int _AP_N2> ap_int_base<_AP_W, _AP_S>::ap_int_base(const int&)’
#    INLINE ap_int_base(
#           ^~~~~~~~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:516:50: error: ‘ap_q_mode’ has not been declared
#    template <int _AP_W2, int _AP_I2, bool _AP_S2, ap_q_mode _AP_Q2,
#                                                   ^~~~~~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:519:51: error: ‘_AP_Q2’ was not declared in this scope
#        const ap_fixed_base<_AP_W2, _AP_I2, _AP_S2, _AP_Q2, _AP_O2, _AP_N2>& op) {
#                                                    ^~~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:519:51: note: suggested alternative: ‘_AP_N2’
#        const ap_fixed_base<_AP_W2, _AP_I2, _AP_S2, _AP_Q2, _AP_O2, _AP_N2>& op) {
#                                                    ^~~~~~
#                                                    _AP_N2
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:519:73: error: template argument 4 is invalid
#        const ap_fixed_base<_AP_W2, _AP_I2, _AP_S2, _AP_Q2, _AP_O2, _AP_N2>& op) {
#                                                                          ^
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:524:50: error: ‘ap_q_mode’ has not been declared
#    template <int _AP_W2, int _AP_I2, bool _AP_S2, ap_q_mode _AP_Q2,
#                                                   ^~~~~~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:527:48: error: ‘_AP_Q2’ was not declared in this scope
#        const af_bit_ref<_AP_W2, _AP_I2, _AP_S2, _AP_Q2, _AP_O2, _AP_N2>& op) {
#                                                 ^~~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:527:48: note: suggested alternative: ‘_AP_N2’
#        const af_bit_ref<_AP_W2, _AP_I2, _AP_S2, _AP_Q2, _AP_O2, _AP_N2>& op) {
#                                                 ^~~~~~
#                                                 _AP_N2
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:527:70: error: template argument 4 is invalid
#        const af_bit_ref<_AP_W2, _AP_I2, _AP_S2, _AP_Q2, _AP_O2, _AP_N2>& op) {
#                                                                       ^
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:526:23: error: ‘template<int _AP_W, bool _AP_S> template<int _AP_W2, int _AP_I2, bool _AP_S2, <declaration error>, ap_o_mode _AP_O2, int _AP_N2> ap_int_base<_AP_W, _AP_S>& ap_int_base<_AP_W, _AP_S>::operator=(const int&)’ cannot be overloaded with ‘template<int _AP_W, bool _AP_S> template<int _AP_W2, int _AP_I2, bool _AP_S2, <declaration error>, ap_o_mode _AP_O2, int _AP_N2> ap_int_base<_AP_W, _AP_S>& ap_int_base<_AP_W, _AP_S>::operator=(const int&)’
#    INLINE ap_int_base& operator=(
#                        ^~~~~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:518:23: note: previous declaration ‘template<int _AP_W, bool _AP_S> template<int _AP_W2, int _AP_I2, bool _AP_S2, <declaration error>, ap_o_mode _AP_O2, int _AP_N2> ap_int_base<_AP_W, _AP_S>& ap_int_base<_AP_W, _AP_S>::operator=(const int&)’
#    INLINE ap_int_base& operator=(
#                        ^~~~~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:532:50: error: ‘ap_q_mode’ has not been declared
#    template <int _AP_W2, int _AP_I2, bool _AP_S2, ap_q_mode _AP_Q2,
#                                                   ^~~~~~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:535:50: error: ‘_AP_Q2’ was not declared in this scope
#        const af_range_ref<_AP_W2, _AP_I2, _AP_S2, _AP_Q2, _AP_O2, _AP_N2>& op) {
#                                                   ^~~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:535:50: note: suggested alternative: ‘_AP_N2’
#        const af_range_ref<_AP_W2, _AP_I2, _AP_S2, _AP_Q2, _AP_O2, _AP_N2>& op) {
#                                                   ^~~~~~
#                                                   _AP_N2
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:535:72: error: template argument 4 is invalid
#        const af_range_ref<_AP_W2, _AP_I2, _AP_S2, _AP_Q2, _AP_O2, _AP_N2>& op) {
#                                                                         ^
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:534:23: error: ‘template<int _AP_W, bool _AP_S> template<int _AP_W2, int _AP_I2, bool _AP_S2, <declaration error>, ap_o_mode _AP_O2, int _AP_N2> ap_int_base<_AP_W, _AP_S>& ap_int_base<_AP_W, _AP_S>::operator=(const int&)’ cannot be overloaded with ‘template<int _AP_W, bool _AP_S> template<int _AP_W2, int _AP_I2, bool _AP_S2, <declaration error>, ap_o_mode _AP_O2, int _AP_N2> ap_int_base<_AP_W, _AP_S>& ap_int_base<_AP_W, _AP_S>::operator=(const int&)’
#    INLINE ap_int_base& operator=(
#                        ^~~~~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:518:23: note: previous declaration ‘template<int _AP_W, bool _AP_S> template<int _AP_W2, int _AP_I2, bool _AP_S2, <declaration error>, ap_o_mode _AP_O2, int _AP_N2> ap_int_base<_AP_W, _AP_S>& ap_int_base<_AP_W, _AP_S>::operator=(const int&)’
#    INLINE ap_int_base& operator=(
#                        ^~~~~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:1192:50: error: ‘ap_q_mode’ has not been declared
#    template <int _AP_W2, int _AP_I2, bool _AP_S2, ap_q_mode _AP_Q2,
#                                                   ^~~~~~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:1196:44: error: ‘_AP_Q2’ was not declared in this scope
#        af_range_ref<_AP_W2, _AP_I2, _AP_S2, _AP_Q2, _AP_O2, _AP_N2> >
#                                             ^~~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:1196:44: note: suggested alternative: ‘_AP_N2’
#        af_range_ref<_AP_W2, _AP_I2, _AP_S2, _AP_Q2, _AP_O2, _AP_N2> >
#                                             ^~~~~~
#                                             _AP_N2
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:1196:66: error: template argument 4 is invalid
#        af_range_ref<_AP_W2, _AP_I2, _AP_S2, _AP_Q2, _AP_O2, _AP_N2> >
#                                                                   ^
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:1196:68: error: template argument 4 is invalid
#        af_range_ref<_AP_W2, _AP_I2, _AP_S2, _AP_Q2, _AP_O2, _AP_N2> >
#                                                                     ^
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:1197:56: error: ‘_AP_Q2’ was not declared in this scope
#    operator,(const af_range_ref<_AP_W2, _AP_I2, _AP_S2, _AP_Q2, _AP_O2, _AP_N2>
#                                                         ^~~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:1197:56: note: suggested alternative: ‘_AP_N2’
#    operator,(const af_range_ref<_AP_W2, _AP_I2, _AP_S2, _AP_Q2, _AP_O2, _AP_N2>
#                                                         ^~~~~~
#                                                         _AP_N2
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:1197:78: error: template argument 4 is invalid
#    operator,(const af_range_ref<_AP_W2, _AP_I2, _AP_S2, _AP_Q2, _AP_O2, _AP_N2>
#                                                                               ^
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:1207:50: error: ‘ap_q_mode’ has not been declared
#    template <int _AP_W2, int _AP_I2, bool _AP_S2, ap_q_mode _AP_Q2,
#                                                   ^~~~~~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:1211:44: error: ‘_AP_Q2’ was not declared in this scope
#        af_range_ref<_AP_W2, _AP_I2, _AP_S2, _AP_Q2, _AP_O2, _AP_N2> >
#                                             ^~~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:1211:44: note: suggested alternative: ‘_AP_N2’
#        af_range_ref<_AP_W2, _AP_I2, _AP_S2, _AP_Q2, _AP_O2, _AP_N2> >
#                                             ^~~~~~
#                                             _AP_N2
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:1211:66: error: template argument 4 is invalid
#        af_range_ref<_AP_W2, _AP_I2, _AP_S2, _AP_Q2, _AP_O2, _AP_N2> >
#                                                                   ^
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:1211:68: error: template argument 4 is invalid
#        af_range_ref<_AP_W2, _AP_I2, _AP_S2, _AP_Q2, _AP_O2, _AP_N2> >
#                                                                     ^
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:1212:50: error: ‘_AP_Q2’ was not declared in this scope
#    operator,(af_range_ref<_AP_W2, _AP_I2, _AP_S2, _AP_Q2, _AP_O2, _AP_N2> &a2) {
#                                                   ^~~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:1212:50: note: suggested alternative: ‘_AP_N2’
#    operator,(af_range_ref<_AP_W2, _AP_I2, _AP_S2, _AP_Q2, _AP_O2, _AP_N2> &a2) {
#                                                   ^~~~~~
#                                                   _AP_N2
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:1212:72: error: template argument 4 is invalid
#    operator,(af_range_ref<_AP_W2, _AP_I2, _AP_S2, _AP_Q2, _AP_O2, _AP_N2> &a2) {
#                                                                         ^
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:1219:50: error: ‘ap_q_mode’ has not been declared
#    template <int _AP_W2, int _AP_I2, bool _AP_S2, ap_q_mode _AP_Q2,
#                                                   ^~~~~~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:1223:56: error: ‘_AP_Q2’ was not declared in this scope
#                      af_bit_ref<_AP_W2, _AP_I2, _AP_S2, _AP_Q2, _AP_O2, _AP_N2> >
#                                                         ^~~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:1223:56: note: suggested alternative: ‘_AP_N2’
#                      af_bit_ref<_AP_W2, _AP_I2, _AP_S2, _AP_Q2, _AP_O2, _AP_N2> >
#                                                         ^~~~~~
#                                                         _AP_N2
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:1223:78: error: template argument 4 is invalid
#                      af_bit_ref<_AP_W2, _AP_I2, _AP_S2, _AP_Q2, _AP_O2, _AP_N2> >
#                                                                               ^
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:1223:80: error: template argument 4 is invalid
#                      af_bit_ref<_AP_W2, _AP_I2, _AP_S2, _AP_Q2, _AP_O2, _AP_N2> >
#                                                                                 ^
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:1224:58: error: ‘_AP_Q2’ was not declared in this scope
#        operator,(const af_bit_ref<_AP_W2, _AP_I2, _AP_S2, _AP_Q2, _AP_O2, _AP_N2>
#                                                           ^~~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:1224:58: note: suggested alternative: ‘_AP_N2’
#        operator,(const af_bit_ref<_AP_W2, _AP_I2, _AP_S2, _AP_Q2, _AP_O2, _AP_N2>
#                                                           ^~~~~~
#                                                           _AP_N2
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:1224:80: error: template argument 4 is invalid
#        operator,(const af_bit_ref<_AP_W2, _AP_I2, _AP_S2, _AP_Q2, _AP_O2, _AP_N2>
#                                                                                 ^
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:1224:7: error: ‘template<int _AP_W, bool _AP_S> template<int _AP_W2, int _AP_I2, bool _AP_S2, <declaration error>, ap_o_mode _AP_O2, int _AP_N2> int ap_int_base<_AP_W, _AP_S>::operator,(const int&) const’ cannot be overloaded with ‘template<int _AP_W, bool _AP_S> template<int _AP_W2, int _AP_I2, bool _AP_S2, <declaration error>, ap_o_mode _AP_O2, int _AP_N2> int ap_int_base<_AP_W, _AP_S>::operator,(const int&) const’
#        operator,(const af_bit_ref<_AP_W2, _AP_I2, _AP_S2, _AP_Q2, _AP_O2, _AP_N2>
#        ^~~~~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:1197:3: note: previous declaration ‘template<int _AP_W, bool _AP_S> template<int _AP_W2, int _AP_I2, bool _AP_S2, <declaration error>, ap_o_mode _AP_O2, int _AP_N2> int ap_int_base<_AP_W, _AP_S>::operator,(const int&) const’
#    operator,(const af_range_ref<_AP_W2, _AP_I2, _AP_S2, _AP_Q2, _AP_O2, _AP_N2>
#    ^~~~~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:1234:50: error: ‘ap_q_mode’ has not been declared
#    template <int _AP_W2, int _AP_I2, bool _AP_S2, ap_q_mode _AP_Q2,
#                                                   ^~~~~~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:1238:56: error: ‘_AP_Q2’ was not declared in this scope
#                      af_bit_ref<_AP_W2, _AP_I2, _AP_S2, _AP_Q2, _AP_O2, _AP_N2> >
#                                                         ^~~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:1238:56: note: suggested alternative: ‘_AP_N2’
#                      af_bit_ref<_AP_W2, _AP_I2, _AP_S2, _AP_Q2, _AP_O2, _AP_N2> >
#                                                         ^~~~~~
#                                                         _AP_N2
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:1238:78: error: template argument 4 is invalid
#                      af_bit_ref<_AP_W2, _AP_I2, _AP_S2, _AP_Q2, _AP_O2, _AP_N2> >
#                                                                               ^
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:1238:80: error: template argument 4 is invalid
#                      af_bit_ref<_AP_W2, _AP_I2, _AP_S2, _AP_Q2, _AP_O2, _AP_N2> >
#                                                                                 ^
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:1240:46: error: ‘_AP_Q2’ was not declared in this scope
#            af_bit_ref<_AP_W2, _AP_I2, _AP_S2, _AP_Q2, _AP_O2, _AP_N2> &a2) {
#                                               ^~~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:1240:46: note: suggested alternative: ‘_AP_N2’
#            af_bit_ref<_AP_W2, _AP_I2, _AP_S2, _AP_Q2, _AP_O2, _AP_N2> &a2) {
#                                               ^~~~~~
#                                               _AP_N2
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:1240:68: error: template argument 4 is invalid
#            af_bit_ref<_AP_W2, _AP_I2, _AP_S2, _AP_Q2, _AP_O2, _AP_N2> &a2) {
#                                                                     ^
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:1239:7: error: ‘template<int _AP_W, bool _AP_S> template<int _AP_W2, int _AP_I2, bool _AP_S2, <declaration error>, ap_o_mode _AP_O2, int _AP_N2> int ap_int_base<_AP_W, _AP_S>::operator,(int&)’ cannot be overloaded with ‘template<int _AP_W, bool _AP_S> template<int _AP_W2, int _AP_I2, bool _AP_S2, <declaration error>, ap_o_mode _AP_O2, int _AP_N2> int ap_int_base<_AP_W, _AP_S>::operator,(int&)’
#        operator,(
#        ^~~~~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:1212:3: note: previous declaration ‘template<int _AP_W, bool _AP_S> template<int _AP_W2, int _AP_I2, bool _AP_S2, <declaration error>, ap_o_mode _AP_O2, int _AP_N2> int ap_int_base<_AP_W, _AP_S>::operator,(int&)’
#    operator,(af_range_ref<_AP_W2, _AP_I2, _AP_S2, _AP_Q2, _AP_O2, _AP_N2> &a2) {
#    ^~~~~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h: In constructor ‘ap_int_base<_AP_W, _AP_S>::ap_int_base(const int&)’:
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:359:18: error: request for member ‘to_ap_int_base’ in ‘op’, which is of non-class type ‘const int’
#      Base::V = op.to_ap_int_base().V;
#                   ^~~~~~~~~~~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h: In constructor ‘ap_int_base<_AP_W, _AP_S>::ap_int_base(const int&)’:
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:409:20: error: request for member ‘get’ in ‘val’, which is of non-class type ‘const int’
#      Base::V = (val.get()).V;
#                     ^~~
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h: In constructor ‘ap_int_base<_AP_W, _AP_S>::ap_int_base(const int&)’:
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:416:28: error: request for member ‘operator bool’ in ‘val’, which is of non-class type ‘const int’
#      Base::V = val.operator bool();
#                             ^~~~
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h: In member function ‘ap_int_base<_AP_W, _AP_S>& ap_int_base<_AP_W, _AP_S>::operator=(const int&)’:
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:520:18: error: request for member ‘to_ap_int_base’ in ‘op’, which is of non-class type ‘const int’
#      Base::V = op.to_ap_int_base().V;
#                   ^~~~~~~~~~~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h: In member function ‘int ap_int_base<_AP_W, _AP_S>::operator,(const int&) const’:
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:1201:46: error: ‘_AP_Q2’ was not declared in this scope
#          af_range_ref<_AP_W2, _AP_I2, _AP_S2, _AP_Q2, _AP_O2, _AP_N2> >(
#                                               ^~~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:1201:46: note: suggested alternative: ‘_AP_N2’
#          af_range_ref<_AP_W2, _AP_I2, _AP_S2, _AP_Q2, _AP_O2, _AP_N2> >(
#                                               ^~~~~~
#                                               _AP_N2
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:1201:68: error: template argument 4 is invalid
#          af_range_ref<_AP_W2, _AP_I2, _AP_S2, _AP_Q2, _AP_O2, _AP_N2> >(
#                                                                     ^
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:1201:70: error: template argument 4 is invalid
#          af_range_ref<_AP_W2, _AP_I2, _AP_S2, _AP_Q2, _AP_O2, _AP_N2> >(
#                                                                       ^
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:1204:73: error: expected ‘>’ before ‘&’ token
#              af_range_ref<_AP_W2, _AP_I2, _AP_S2, _AP_Q2, _AP_O2, _AP_N2>&>(a2));
#                                                                          ^
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:1204:73: error: expected ‘(’ before ‘&’ token
#              af_range_ref<_AP_W2, _AP_I2, _AP_S2, _AP_Q2, _AP_O2, _AP_N2>&>(a2));
#                                                                          ^
#                                                                          (
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:1204:74: error: expected primary-expression before ‘>’ token
#              af_range_ref<_AP_W2, _AP_I2, _AP_S2, _AP_Q2, _AP_O2, _AP_N2>&>(a2));
#                                                                           ^
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h: In member function ‘int ap_int_base<_AP_W, _AP_S>::operator,(int&)’:
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:1215:46: error: ‘_AP_Q2’ was not declared in this scope
#          af_range_ref<_AP_W2, _AP_I2, _AP_S2, _AP_Q2, _AP_O2, _AP_N2> >(*this,
#                                               ^~~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:1215:46: note: suggested alternative: ‘_AP_N2’
#          af_range_ref<_AP_W2, _AP_I2, _AP_S2, _AP_Q2, _AP_O2, _AP_N2> >(*this,
#                                               ^~~~~~
#                                               _AP_N2
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:1215:68: error: template argument 4 is invalid
#          af_range_ref<_AP_W2, _AP_I2, _AP_S2, _AP_Q2, _AP_O2, _AP_N2> >(*this,
#                                                                     ^
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:1215:70: error: template argument 4 is invalid
#          af_range_ref<_AP_W2, _AP_I2, _AP_S2, _AP_Q2, _AP_O2, _AP_N2> >(*this,
#                                                                       ^
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h: In member function ‘int ap_int_base<_AP_W, _AP_S>::operator,(const int&) const’:
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:1228:44: error: ‘_AP_Q2’ was not declared in this scope
#          af_bit_ref<_AP_W2, _AP_I2, _AP_S2, _AP_Q2, _AP_O2, _AP_N2> >(
#                                             ^~~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:1228:44: note: suggested alternative: ‘_AP_N2’
#          af_bit_ref<_AP_W2, _AP_I2, _AP_S2, _AP_Q2, _AP_O2, _AP_N2> >(
#                                             ^~~~~~
#                                             _AP_N2
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:1228:66: error: template argument 4 is invalid
#          af_bit_ref<_AP_W2, _AP_I2, _AP_S2, _AP_Q2, _AP_O2, _AP_N2> >(
#                                                                   ^
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:1228:68: error: template argument 4 is invalid
#          af_bit_ref<_AP_W2, _AP_I2, _AP_S2, _AP_Q2, _AP_O2, _AP_N2> >(
#                                                                     ^
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:1230:78: error: expected ‘>’ before ‘&’ token
#          const_cast<af_bit_ref<_AP_W2, _AP_I2, _AP_S2, _AP_Q2, _AP_O2, _AP_N2>&>(
#                                                                               ^
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:1230:78: error: expected ‘(’ before ‘&’ token
#          const_cast<af_bit_ref<_AP_W2, _AP_I2, _AP_S2, _AP_Q2, _AP_O2, _AP_N2>&>(
#                                                                               ^
#                                                                               (
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:1230:79: error: expected primary-expression before ‘>’ token
#          const_cast<af_bit_ref<_AP_W2, _AP_I2, _AP_S2, _AP_Q2, _AP_O2, _AP_N2>&>(
#                                                                                ^
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h: In member function ‘int ap_int_base<_AP_W, _AP_S>::operator,(int&)’:
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:1243:44: error: ‘_AP_Q2’ was not declared in this scope
#          af_bit_ref<_AP_W2, _AP_I2, _AP_S2, _AP_Q2, _AP_O2, _AP_N2> >(*this, a2);
#                                             ^~~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:1243:44: note: suggested alternative: ‘_AP_N2’
#          af_bit_ref<_AP_W2, _AP_I2, _AP_S2, _AP_Q2, _AP_O2, _AP_N2> >(*this, a2);
#                                             ^~~~~~
#                                             _AP_N2
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:1243:66: error: template argument 4 is invalid
#          af_bit_ref<_AP_W2, _AP_I2, _AP_S2, _AP_Q2, _AP_O2, _AP_N2> >(*this, a2);
#                                                                   ^
# /opt/xilinx/Vivado/2019.2/include/ap_int_base.h:1243:68: error: template argument 4 is invalid
#          af_bit_ref<_AP_W2, _AP_I2, _AP_S2, _AP_Q2, _AP_O2, _AP_N2> >(*this, a2);
#                                                                     ^
# In file included from /opt/xilinx/Vivado/2019.2/include/ap_int.h:56,
#                  from typedefs.h:9,
#                  from digitrec.h:9,
#                  from digitrec.cpp:7:
# /opt/xilinx/Vivado/2019.2/include/ap_int_ref.h: At global scope:
# /opt/xilinx/Vivado/2019.2/include/ap_int_ref.h:160:50: error: ‘ap_q_mode’ has not been declared
#    template <int _AP_W3, int _AP_I3, bool _AP_S3, ap_q_mode _AP_Q3,
#                                                   ^~~~~~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_int_ref.h:163:50: error: ‘_AP_Q3’ was not declared in this scope
#        const af_range_ref<_AP_W3, _AP_I3, _AP_S3, _AP_Q3, _AP_O3, _AP_N3>& val) {
#                                                   ^~~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_int_ref.h:163:50: note: suggested alternative: ‘_AP_N3’
#        const af_range_ref<_AP_W3, _AP_I3, _AP_S3, _AP_Q3, _AP_O3, _AP_N3>& val) {
#                                                   ^~~~~~
#                                                   _AP_N3
# /opt/xilinx/Vivado/2019.2/include/ap_int_ref.h:163:72: error: template argument 4 is invalid
#        const af_range_ref<_AP_W3, _AP_I3, _AP_S3, _AP_Q3, _AP_O3, _AP_N3>& val) {
#                                                                         ^
# /opt/xilinx/Vivado/2019.2/include/ap_int_ref.h:167:50: error: ‘ap_q_mode’ has not been declared
#    template <int _AP_W3, int _AP_I3, bool _AP_S3, ap_q_mode _AP_Q3,
#                                                   ^~~~~~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_int_ref.h:170:51: error: ‘_AP_Q3’ was not declared in this scope
#        const ap_fixed_base<_AP_W3, _AP_I3, _AP_S3, _AP_Q3, _AP_O3, _AP_N3>&
#                                                    ^~~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_int_ref.h:170:51: note: suggested alternative: ‘_AP_N3’
#        const ap_fixed_base<_AP_W3, _AP_I3, _AP_S3, _AP_Q3, _AP_O3, _AP_N3>&
#                                                    ^~~~~~
#                                                    _AP_N3
# /opt/xilinx/Vivado/2019.2/include/ap_int_ref.h:170:73: error: template argument 4 is invalid
#        const ap_fixed_base<_AP_W3, _AP_I3, _AP_S3, _AP_Q3, _AP_O3, _AP_N3>&
#                                                                          ^
# /opt/xilinx/Vivado/2019.2/include/ap_int_ref.h:169:25: error: ‘template<int _AP_W1, class _AP_T1, int _AP_W2, class _AP_T2> template<int _AP_W3, int _AP_I3, bool _AP_S3, <declaration error>, ap_o_mode _AP_O3, int _AP_N3> ap_concat_ref<_AP_W1, _AP_T1, _AP_W2, _AP_T2>& ap_concat_ref<_AP_W1, _AP_T1, _AP_W2, _AP_T2>::operator=(const int&)’ cannot be overloaded with ‘template<int _AP_W1, class _AP_T1, int _AP_W2, class _AP_T2> template<int _AP_W3, int _AP_I3, bool _AP_S3, <declaration error>, ap_o_mode _AP_O3, int _AP_N3> ap_concat_ref<_AP_W1, _AP_T1, _AP_W2, _AP_T2>& ap_concat_ref<_AP_W1, _AP_T1, _AP_W2, _AP_T2>::operator=(const int&)’
#    INLINE ap_concat_ref& operator=(
#                          ^~~~~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_int_ref.h:162:25: note: previous declaration ‘template<int _AP_W1, class _AP_T1, int _AP_W2, class _AP_T2> template<int _AP_W3, int _AP_I3, bool _AP_S3, <declaration error>, ap_o_mode _AP_O3, int _AP_N3> ap_concat_ref<_AP_W1, _AP_T1, _AP_W2, _AP_T2>& ap_concat_ref<_AP_W1, _AP_T1, _AP_W2, _AP_T2>::operator=(const int&)’
#    INLINE ap_concat_ref& operator=(
#                          ^~~~~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_int_ref.h:175:50: error: ‘ap_q_mode’ has not been declared
#    template <int _AP_W3, int _AP_I3, bool _AP_S3, ap_q_mode _AP_Q3,
#                                                   ^~~~~~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_int_ref.h:178:48: error: ‘_AP_Q3’ was not declared in this scope
# ...
#  AF_REL_OP_WITH_AP_INT(!=)
#  ^~~~~~~~~~~~~~~~~~~~~
# In file included from /opt/xilinx/Vivado/2019.2/include/ap_fixed.h:56,
#                  from /opt/xilinx/Vivado/2019.2/include/ap_int.h:367,
#                  from typedefs.h:9,
#                  from digitrec.h:9,
#                  from digitrec.cpp:7:
# /opt/xilinx/Vivado/2019.2/include/ap_fixed_ref.h:734:47: error: ‘ap_q_mode’ has not been declared
#    template <int _AP_W, int _AP_I, bool _AP_S, ap_q_mode _AP_Q,            \
#                                                ^~~~~~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_fixed_ref.h:747:1: note: in expansion of macro ‘AF_REF_REL_OP_WITH_AP_INT’
#  AF_REF_REL_OP_WITH_AP_INT(!=)
#  ^~~~~~~~~~~~~~~~~~~~~~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_fixed_ref.h:738:45: error: ‘_AP_Q’ was not declared in this scope
#        const af_bit_ref<_AP_W, _AP_I, _AP_S, _AP_Q, _AP_O, _AP_N>& op) {   \
#                                              ^~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_fixed_ref.h:747:1: note: in expansion of macro ‘AF_REF_REL_OP_WITH_AP_INT’
#  AF_REF_REL_OP_WITH_AP_INT(!=)
#  ^~~~~~~~~~~~~~~~~~~~~~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_fixed_ref.h:738:45: note: suggested alternative: ‘_AP_N’
#        const af_bit_ref<_AP_W, _AP_I, _AP_S, _AP_Q, _AP_O, _AP_N>& op) {   \
#                                              ^~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_fixed_ref.h:747:1: note: in expansion of macro ‘AF_REF_REL_OP_WITH_AP_INT’
#  AF_REF_REL_OP_WITH_AP_INT(!=)
#  ^~~~~~~~~~~~~~~~~~~~~~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_fixed_ref.h:738:64: error: template argument 4 is invalid
#        const af_bit_ref<_AP_W, _AP_I, _AP_S, _AP_Q, _AP_O, _AP_N>& op) {   \
#                                                                 ^
# /opt/xilinx/Vivado/2019.2/include/ap_fixed_ref.h:747:1: note: in expansion of macro ‘AF_REF_REL_OP_WITH_AP_INT’
#  AF_REF_REL_OP_WITH_AP_INT(!=)
#  ^~~~~~~~~~~~~~~~~~~~~~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_fixed_ref.h:736:15: error: redefinition of ‘template<int _AP_W, int _AP_I, bool _AP_S, <declaration error>, ap_o_mode _AP_O, int _AP_N, int _AP_W2, bool _AP_S2> bool operator!=(const ap_int_base<_AP_W2, _AP_S2>&, const int&)’
#    INLINE bool operator REL_OP(                                            \
#                ^~~~~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_fixed_ref.h:747:1: note: in expansion of macro ‘AF_REF_REL_OP_WITH_AP_INT’
#  AF_REF_REL_OP_WITH_AP_INT(!=)
#  ^~~~~~~~~~~~~~~~~~~~~~~~~
# In file included from /opt/xilinx/Vivado/2019.2/include/ap_fixed.h:55,
#                  from /opt/xilinx/Vivado/2019.2/include/ap_int.h:367,
#                  from typedefs.h:9,
#                  from digitrec.h:9,
#                  from digitrec.cpp:7:
# /opt/xilinx/Vivado/2019.2/include/ap_fixed_base.h:2277:15: note: ‘template<int _AP_W, int _AP_I, bool _AP_S, <declaration error>, ap_o_mode _AP_O, int _AP_N, int _AP_W2, bool _AP_S2> bool operator!=(const ap_int_base<_AP_W2, _AP_S2>&, const int&)’ previously declared here
#    INLINE bool operator REL_OP(                                              \
#                ^~~~~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_fixed_base.h:2322:1: note: in expansion of macro ‘AF_REL_OP_WITH_AP_INT’
#  AF_REL_OP_WITH_AP_INT(!=)
#  ^~~~~~~~~~~~~~~~~~~~~
# In file included from /opt/xilinx/Vivado/2019.2/include/ap_int.h:367,
#                  from typedefs.h:9,
#                  from digitrec.h:9,
#                  from digitrec.cpp:7:
# /opt/xilinx/Vivado/2019.2/include/ap_fixed.h:62:33: error: ‘ap_q_mode’ has not been declared
#  template <int _AP_W, int _AP_I, ap_q_mode _AP_Q, ap_o_mode _AP_O, int _AP_N>
#                                  ^~~~~~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_fixed.h:63:53: error: ‘_AP_Q’ was not declared in this scope
#  struct ap_fixed : ap_fixed_base<_AP_W, _AP_I, true, _AP_Q, _AP_O, _AP_N> {
#                                                      ^~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_fixed.h:63:53: note: suggested alternative: ‘_AP_N’
#  struct ap_fixed : ap_fixed_base<_AP_W, _AP_I, true, _AP_Q, _AP_O, _AP_N> {
#                                                      ^~~~~
#                                                      _AP_N
# /opt/xilinx/Vivado/2019.2/include/ap_fixed.h:63:72: error: template argument 4 is invalid
#  struct ap_fixed : ap_fixed_base<_AP_W, _AP_I, true, _AP_Q, _AP_O, _AP_N> {
#                                                                         ^
# /opt/xilinx/Vivado/2019.2/include/ap_fixed.h:228:33: error: ‘ap_q_mode’ has not been declared
#  template <int _AP_W, int _AP_I, ap_q_mode _AP_Q, ap_o_mode _AP_O, int _AP_N>
#                                  ^~~~~~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_fixed.h:229:55: error: ‘_AP_Q’ was not declared in this scope
#  struct ap_ufixed : ap_fixed_base<_AP_W, _AP_I, false, _AP_Q, _AP_O, _AP_N> {
#                                                        ^~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_fixed.h:229:55: note: suggested alternative: ‘_AP_N’
#  struct ap_ufixed : ap_fixed_base<_AP_W, _AP_I, false, _AP_Q, _AP_O, _AP_N> {
#                                                        ^~~~~
#                                                        _AP_N
# /opt/xilinx/Vivado/2019.2/include/ap_fixed.h:229:74: error: template argument 4 is invalid
#  struct ap_ufixed : ap_fixed_base<_AP_W, _AP_I, false, _AP_Q, _AP_O, _AP_N> {
#                                                                           ^
# In file included from /opt/xilinx/Vivado/2019.2/include/ap_fixed.h:398,
#                  from /opt/xilinx/Vivado/2019.2/include/ap_int.h:367,
#                  from typedefs.h:9,
#                  from digitrec.h:9,
#                  from digitrec.cpp:7:
# /opt/xilinx/Vivado/2019.2/include/ap_fixed_special.h:89:33: error: ‘ap_q_mode’ has not been declared
#  template <int _AP_W, int _AP_I, ap_q_mode _AP_Q, ap_o_mode _AP_O, int _AP_N>
#                                  ^~~~~~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_fixed_special.h:90:38: error: ‘_AP_Q’ was not declared in this scope
#  class complex<ap_fixed<_AP_W, _AP_I, _AP_Q, _AP_O, _AP_N> > {
#                                       ^~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_fixed_special.h:90:38: note: suggested alternative: ‘_AP_N’
#  class complex<ap_fixed<_AP_W, _AP_I, _AP_Q, _AP_O, _AP_N> > {
#                                       ^~~~~
#                                       _AP_N
# /opt/xilinx/Vivado/2019.2/include/ap_fixed_special.h:90:57: error: template argument 3 is invalid
#  class complex<ap_fixed<_AP_W, _AP_I, _AP_Q, _AP_O, _AP_N> > {
#                                                          ^
# /opt/xilinx/Vivado/2019.2/include/ap_fixed_special.h:90:59: error: template argument 1 is invalid
#  class complex<ap_fixed<_AP_W, _AP_I, _AP_Q, _AP_O, _AP_N> > {
#                                                            ^
# /opt/xilinx/Vivado/2019.2/include/ap_fixed_special.h:221:33: error: ‘ap_q_mode’ has not been declared
#  template <int _AP_W, int _AP_I, ap_q_mode _AP_Q, ap_o_mode _AP_O, int _AP_N>
#                                  ^~~~~~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_fixed_special.h:223:42: error: ‘_AP_Q’ was not declared in this scope
#      const complex<ap_fixed<_AP_W, _AP_I, _AP_Q, _AP_O, _AP_N> > &__x,
#                                           ^~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_fixed_special.h:223:42: note: suggested alternative: ‘_AP_N’
#      const complex<ap_fixed<_AP_W, _AP_I, _AP_Q, _AP_O, _AP_N> > &__x,
#                                           ^~~~~
#                                           _AP_N
# /opt/xilinx/Vivado/2019.2/include/ap_fixed_special.h:223:61: error: template argument 3 is invalid
#      const complex<ap_fixed<_AP_W, _AP_I, _AP_Q, _AP_O, _AP_N> > &__x,
#                                                              ^
# /opt/xilinx/Vivado/2019.2/include/ap_fixed_special.h:223:63: error: template argument 1 is invalid
#      const complex<ap_fixed<_AP_W, _AP_I, _AP_Q, _AP_O, _AP_N> > &__x,
#                                                                ^
# /opt/xilinx/Vivado/2019.2/include/ap_fixed_special.h:224:34: error: ‘_AP_Q’ was not declared in this scope
#      const ap_fixed<_AP_W, _AP_I, _AP_Q, _AP_O, _AP_N> &__y) {
#                                   ^~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_fixed_special.h:224:34: note: suggested alternative: ‘_AP_N’
#      const ap_fixed<_AP_W, _AP_I, _AP_Q, _AP_O, _AP_N> &__y) {
#                                   ^~~~~
#                                   _AP_N
# /opt/xilinx/Vivado/2019.2/include/ap_fixed_special.h:224:53: error: template argument 3 is invalid
#      const ap_fixed<_AP_W, _AP_I, _AP_Q, _AP_O, _AP_N> &__y) {
#                                                      ^
# /opt/xilinx/Vivado/2019.2/include/ap_fixed_special.h:224:59: error: ‘bool std::operator==(const int&, const int&)’ must have an argument of class or enumerated type
#      const ap_fixed<_AP_W, _AP_I, _AP_Q, _AP_O, _AP_N> &__y) {
#                                                            ^
# /opt/xilinx/Vivado/2019.2/include/ap_fixed_special.h:230:33: error: ‘ap_q_mode’ has not been declared
#  template <int _AP_W, int _AP_I, ap_q_mode _AP_Q, ap_o_mode _AP_O, int _AP_N>
#                                  ^~~~~~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_fixed_special.h:232:34: error: ‘_AP_Q’ was not declared in this scope
#      const ap_fixed<_AP_W, _AP_I, _AP_Q, _AP_O, _AP_N> &__x,
#                                   ^~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_fixed_special.h:232:34: note: suggested alternative: ‘_AP_N’
#      const ap_fixed<_AP_W, _AP_I, _AP_Q, _AP_O, _AP_N> &__x,
#                                   ^~~~~
#                                   _AP_N
# /opt/xilinx/Vivado/2019.2/include/ap_fixed_special.h:232:53: error: template argument 3 is invalid
#      const ap_fixed<_AP_W, _AP_I, _AP_Q, _AP_O, _AP_N> &__x,
#                                                      ^
# /opt/xilinx/Vivado/2019.2/include/ap_fixed_special.h:233:42: error: ‘_AP_Q’ was not declared in this scope
#      const complex<ap_fixed<_AP_W, _AP_I, _AP_Q, _AP_O, _AP_N> > &__y) {
#                                           ^~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_fixed_special.h:233:42: note: suggested alternative: ‘_AP_N’
#      const complex<ap_fixed<_AP_W, _AP_I, _AP_Q, _AP_O, _AP_N> > &__y) {
#                                           ^~~~~
#                                           _AP_N
# /opt/xilinx/Vivado/2019.2/include/ap_fixed_special.h:233:61: error: template argument 3 is invalid
#      const complex<ap_fixed<_AP_W, _AP_I, _AP_Q, _AP_O, _AP_N> > &__y) {
#                                                              ^
# /opt/xilinx/Vivado/2019.2/include/ap_fixed_special.h:233:63: error: template argument 1 is invalid
#      const complex<ap_fixed<_AP_W, _AP_I, _AP_Q, _AP_O, _AP_N> > &__y) {
#                                                                ^
# /opt/xilinx/Vivado/2019.2/include/ap_fixed_special.h:233:69: error: ‘bool std::operator==(const int&, const int&)’ must have an argument of class or enumerated type
#      const complex<ap_fixed<_AP_W, _AP_I, _AP_Q, _AP_O, _AP_N> > &__y) {
#                                                                      ^
# /opt/xilinx/Vivado/2019.2/include/ap_fixed_special.h:239:33: error: ‘ap_q_mode’ has not been declared
#  template <int _AP_W, int _AP_I, ap_q_mode _AP_Q, ap_o_mode _AP_O, int _AP_N>
#                                  ^~~~~~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_fixed_special.h:241:42: error: ‘_AP_Q’ was not declared in this scope
#      const complex<ap_fixed<_AP_W, _AP_I, _AP_Q, _AP_O, _AP_N> > &__x,
#                                           ^~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_fixed_special.h:241:42: note: suggested alternative: ‘_AP_N’
#      const complex<ap_fixed<_AP_W, _AP_I, _AP_Q, _AP_O, _AP_N> > &__x,
#                                           ^~~~~
#                                           _AP_N
# /opt/xilinx/Vivado/2019.2/include/ap_fixed_special.h:241:61: error: template argument 3 is invalid
#      const complex<ap_fixed<_AP_W, _AP_I, _AP_Q, _AP_O, _AP_N> > &__x,
#                                                              ^
# /opt/xilinx/Vivado/2019.2/include/ap_fixed_special.h:241:63: error: template argument 1 is invalid
#      const complex<ap_fixed<_AP_W, _AP_I, _AP_Q, _AP_O, _AP_N> > &__x,
#                                                                ^
# /opt/xilinx/Vivado/2019.2/include/ap_fixed_special.h:242:34: error: ‘_AP_Q’ was not declared in this scope
#      const ap_fixed<_AP_W, _AP_I, _AP_Q, _AP_O, _AP_N> &__y) {
#                                   ^~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_fixed_special.h:242:34: note: suggested alternative: ‘_AP_N’
#      const ap_fixed<_AP_W, _AP_I, _AP_Q, _AP_O, _AP_N> &__y) {
#                                   ^~~~~
#                                   _AP_N
# /opt/xilinx/Vivado/2019.2/include/ap_fixed_special.h:242:53: error: template argument 3 is invalid
#      const ap_fixed<_AP_W, _AP_I, _AP_Q, _AP_O, _AP_N> &__y) {
#                                                      ^
# /opt/xilinx/Vivado/2019.2/include/ap_fixed_special.h:242:59: error: ‘bool std::operator!=(const int&, const int&)’ must have an argument of class or enumerated type
#      const ap_fixed<_AP_W, _AP_I, _AP_Q, _AP_O, _AP_N> &__y) {
#                                                            ^
# /opt/xilinx/Vivado/2019.2/include/ap_fixed_special.h:248:33: error: ‘ap_q_mode’ has not been declared
#  template <int _AP_W, int _AP_I, ap_q_mode _AP_Q, ap_o_mode _AP_O, int _AP_N>
#                                  ^~~~~~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_fixed_special.h:250:34: error: ‘_AP_Q’ was not declared in this scope
#      const ap_fixed<_AP_W, _AP_I, _AP_Q, _AP_O, _AP_N> &__x,
#                                   ^~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_fixed_special.h:250:34: note: suggested alternative: ‘_AP_N’
#      const ap_fixed<_AP_W, _AP_I, _AP_Q, _AP_O, _AP_N> &__x,
#                                   ^~~~~
#                                   _AP_N
# /opt/xilinx/Vivado/2019.2/include/ap_fixed_special.h:250:53: error: template argument 3 is invalid
#      const ap_fixed<_AP_W, _AP_I, _AP_Q, _AP_O, _AP_N> &__x,
#                                                      ^
# /opt/xilinx/Vivado/2019.2/include/ap_fixed_special.h:251:42: error: ‘_AP_Q’ was not declared in this scope
#      const complex<ap_fixed<_AP_W, _AP_I, _AP_Q, _AP_O, _AP_N> > &__y) {
#                                           ^~~~~
# /opt/xilinx/Vivado/2019.2/include/ap_fixed_special.h:251:42: note: suggested alternative: ‘_AP_N’
#      const complex<ap_fixed<_AP_W, _AP_I, _AP_Q, _AP_O, _AP_N> > &__y) {
#                                           ^~~~~
#                                           _AP_N
# /opt/xilinx/Vivado/2019.2/include/ap_fixed_special.h:251:61: error: template argument 3 is invalid
#      const complex<ap_fixed<_AP_W, _AP_I, _AP_Q, _AP_O, _AP_N> > &__y) {
#                                                              ^
# /opt/xilinx/Vivado/2019.2/include/ap_fixed_special.h:251:63: error: template argument 1 is invalid
#      const complex<ap_fixed<_AP_W, _AP_I, _AP_Q, _AP_O, _AP_N> > &__y) {
#                                                                ^
# /opt/xilinx/Vivado/2019.2/include/ap_fixed_special.h:251:69: error: ‘bool std::operator!=(const int&, const int&)’ must have an argument of class or enumerated type
#      const complex<ap_fixed<_AP_W, _AP_I, _AP_Q, _AP_O, _AP_N> > &__y) {
#                                                                      ^
# digitrec.cpp: In function ‘bit4 digitrec(digit)’:
# digitrec.cpp:35:3: warning: no return statement in function returning non-void [-Wreturn-type]
#    }
#    ^
# digitrec.cpp: At global scope:
# digitrec.cpp:38:3: error: expected unqualified-id before ‘return’
#    return knn_vote(knn_set);
#    ^~~~~~
# digitrec.cpp:39:1: error: expected declaration before ‘}’ token
#  }
#  ^
# make: *** [Makefile:30: digitrec_3-nn_tb] Error 1
#
# Compilation failed. Updating prompt with error messages.
# Error during API request: 429 Resource has been exhausted (e.g. check quota).
# Compilation attempts: 3
